# %% [markdown]
# *Yigao Li*
# *Nov 5, 2018*

# %%
import os
import spacy
import wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud

directory = "ner"
nlp = spacy.load("en")
for filename in os.listdir(directory):
    with open(directory + "/" + filename, encoding = "utf-8") as f:
        text = f.read()
#nlp = en_core_web_sm.load()
#nlp = spacy.load("en_core_web_sm")

    doc = nlp(text)
# print entity type after each token
#    for token in doc:
#        print(token, token.ent_type_, end = ' ')
# just print the entities in the document
    entities = " "
    for ent in doc.ents:
        entities = entities + ent.text + " "
    wordcloud = WordCloud(width = 800, height = 800, background_color = "white",
                          stopwords = None, min_font_size = 10).generate(entities)
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()
    print(filename[:-4])
# Out:
# 01 Genre News Article Domain Finance
# 02 Genre Short Story Domain Crime
# 03 Genre Academic Paper Domain Motor
# 04 Genre Chat Session Domain Graduate Application
# 05 Genre Review Domain Movie
# 06 Genre Curriculum Vitae Domain Politics
# 07 Genre Blog Domain Filmmaker
# 08 Genre Exam Essay Domain GRE
# 09 Genre Social Media Domain Sports
# 10 Genre Bibliography Domain Memoir
